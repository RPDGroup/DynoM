# %% [markdown]
# ## Data Process

# %% [markdown]
# ### Step1_Convert_Fasta_Into_Pkl

# %%
# %cd /opt/data/private/test_github_dynom/Jqt_Test/DynoM
# !python3 -m data_processed.rcsb_script.step2_fasta_file_processed \
    --input_fasta_dir /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step1_Convert_Fasta_Into_Pkl/Input \
    --one_pdb_output_pkl_dir /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step1_Convert_Fasta_Into_Pkl \
    --final_pkl_file /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step1_Convert_Fasta_Into_Pkl/Output/9R71.pkl \
    --temporary_deleted \
    --mode complex
# Out:
# /opt/data/private/test_github_dynom/Jqt_Test/DynoM
# No PDB ID filter provided. Processing all FASTA files.
# Total number of fasta files: 1
# Number of fasta files to process: 1
# Using 82 processes
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 31.89it/s]
# Number of successful fasta files: 1
# Total pkl files: 1, final merged pkl saved at: /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step1_Convert_Fasta_Into_Pkl/Output/9R71.pkl
# Temporary pkl files deleted.

# %% [markdown]
# ### Step2 Representation Generation

# %% [markdown]
# #### Step 2-1 MSA Generation

# %%
# %cd /opt/data/private/test_github_dynom/Jqt_Test/DynoM
# !python3 -m data_processed.rcsb_script.step5_representation_generation.step2_get_msa_from_protenixAPI \
    --input_file /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step1_Convert_Fasta_Into_Pkl/Output/9R71.pkl \
    --msa_out_dir /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/01_MAS_Generation/Output \
    --log_file /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/01_MAS_Generation/Output/msa.log \
    --max_workers 1
# Out:
# /opt/data/private/test_github_dynom/Jqt_Test/DynoM
# release_data/components.v20240608.cif
# Try to find the ccd cache data in the code directory for inference.
# PKL input detected
# Total number of records: 1
# All tasks submitted.
# Processing 9R71 in /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/01_MAS_Generation/Output/9R71
# 2026-04-08 12:28:12,541 [/opt/data/private/test_github_dynom/Jqt_Test/DynoM/data_processed/protenix/protenix/web_service/colab_request_utils.py:209] INFO protenix.web_service.colab_request_utils: Msa server is running.
# Completed: 9R71

# %% [markdown]
# #### Step 2-2: JSON Construction for Representation Input

# %%
# %cd /opt/data/private/test_github_dynom/Jqt_Test/DynoM
# !python3 -m data_processed.rcsb_script.step5_representation_generation.step3_af3_input_json \
    --input_file /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step1_Convert_Fasta_Into_Pkl/Output/9R71.pkl \
    --msa_results_dir /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/01_MAS_Generation/Output \
    --one_json_output_dir /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/02_JSON_Construction/tmp \
    --merge_json_output_dir /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/02_JSON_Construction/Output \
    --merge_json_output_name 9R71 \
    --pairing_db 'uniref100'
# Out:
# /opt/data/private/test_github_dynom/Jqt_Test/DynoM
# Processing MSA directory: /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/01_MAS_Generation/Output/9R71
# Saved MSA results for 9R71 to /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/02_JSON_Construction/tmp/9R71_msa_results.json
# Errors encountered with PDB IDs: []
# Merged JSON file has been saved to /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/02_JSON_Construction/Output/9R71.json
# Merged JSON saved to: /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/02_JSON_Construction/Output/9R71.json

# %% [markdown]
# #### Step 2-3: Environment Setup

# %%
# 1. Create and activate a new Conda environment
conda create -n protenix_env python=3.10 -y
conda activate protenix_env

# 2. Navigate to the Protenix directory and install dependencies
cd ./data_processed/protenix
pip3 install -e .
# 3. Install additional dependencies
pip install dm-tree

# %% [markdown]
# #### Step 2-4: Representation Generation

# %%
pip uninstall deepspeed
pip install deepspeed==0.15.1

# %%
# conda activate the protenix environment.Note:place model_v0.2.0.pt in protenix/release_data/checkpoint
# %cd /opt/data/private/test_github_dynom/Jqt_Test/DynoM/data_processed/protenix
# !bash inference_demo_1.sh
# Out:
# /opt/data/private/test_github_dynom/Jqt_Test/DynoM/data_processed/protenix
# /opt/conda/envs/protenix_env/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# release_data/components.v20240608.cif
# Try to find the ccd cache data in the code directory for inference.
# [2026-04-08 12:29:16,758] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# configs.only_encoder:  True
# 2026-04-08 12:29:18,527 [/opt/data/private/test_github_dynom/Jqt_Test/DynoM/data_processed/protenix/runner/inference.py:164] INFO __main__: Distributed environment: world size: 1, global rank: 0, local rank: 0
# ...

# %% [markdown]
# ### Step 3: Representation Retrieval by Sequence

# %%
# %cd /opt/data/private/test_github_dynom/Jqt_Test/DynoM

# !python3 -m data_processed.rcsb_script.step6_af3rep_corresponding_seqs \
    --input_pkl /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step1_Convert_Fasta_Into_Pkl/Output/9R71.pkl \
    --output_pkl /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step3_Representation_Retrieval_by_Sequence/Output/9R71.pkl
# Out:
# /opt/data/private/test_github_dynom/Jqt_Test/DynoM
# Saved successfully: /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step3_Representation_Retrieval_by_Sequence/Output/9R71.pkl

# %% [markdown]
# ### Inference

# %%
# %cd /opt/data/private/test_github_dynom/Jqt_Test/DynoM
# !python Predict.py \
    --gen_dataset_test_gen_dataset /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step1_Convert_Fasta_Into_Pkl/Output/9R71.pkl \
    --alphafold3_cfg_seqres_to_index_path /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step3_Representation_Retrieval_by_Sequence/Output/9R71.pkl \
    --alphafold3_cfg_repr_data_root /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/01_Data_Process/Step2_Representation_Generation/04_Representaion_Generation \
    --gen_batch_size 10 \
    --gen_num_samples 2 \
    --model_ckpt_path /opt/data/private/test_github_dynom/Jqt_Test/DynoM/checkpoint/DynoM.ckpt \
    --output_dir /opt/data/private/test_github_dynom/Jqt_Test/DynoM/example/Test_Task/ADK/02_Inference/Output
